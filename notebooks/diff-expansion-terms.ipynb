# %% [markdown]
# ### This notebook outputs the difference between expansion terms of two given methods

# %%
import json
import tqdm
from pathlib import Path

# %%
def queries_exp_terms_list_to_dict(queries_exp_terms_list):
    queries_exp_terms_dict = {}
    for i in range(len(queries_exp_terms_list)):
        queries_exp_terms_dict[queries_exp_terms_list[i]['topicNumber']] = queries_exp_terms_list[i]
    return queries_exp_terms_dict

# %%
def methods_exp_terms_diff(method1_terms, method2_terms):
    elements_diff = set()
    method1_exclude_2 = set(method1_terms) - set(method2_terms)
    method2_exclude_1 = set(method2_terms) - set(method1_terms)
    elements_diff.update(method1_exclude_2)
    elements_diff.update(method2_exclude_1)
    return method1_exclude_2, method2_exclude_1

# %%
# Get the difference between the topk expansion terms of (method1 vs. method2) and (method2 vs. method1) 
def get_method_diff(method1, method2, topk=10):
    # iterate over queries
    diff_per_q = {}
    for q in method1:
        if q not in method2:
            print(q)
            continue
        method1_exp_terms = []
        method2_exp_terms = []
        for i in range(topk):
            method1_exp_terms.append(method1[q]['terms'][i]['word'])
            method2_exp_terms.append(method2[q]['terms'][i]['word'])
        method1_ex_2, method2_ex_1 = methods_exp_terms_diff(method1_exp_terms[:topk], method2_exp_terms[:topk])
        diff_per_q.setdefault(q, {})
        # method1_ex_2: method1 expansion terms excluding method2 expansion terms (expansion terms only in method1)
        # method2_ex_1: method2 expansion terms excluding method1 expansion terms (expansion terms only in method2)
        diff_per_q[q] = {'topicNumber':q, 'diff_terms':{'method1_ex_2':method1_ex_2, 'method2_ex_1':method2_ex_1}} 
    return diff_per_q

# %% [markdown]
# ## Example

# %% [markdown]
# ### Read query into a dictionary of {q_id:q_text}

# %%
queries_file = '../data/robust/stopped_queries_lower.txt'

# %%
queries = {}
with open(queries_file) as f:
    for line in tqdm.tqdm(f):
        q_id , q_text = line.strip().split('\t')
        queries[q_id] = q_text
# Out:
# 250it [00:00, 191345.99it/s]

# %% [markdown]
# ### Read expansion terms into a dictionary of {q_id: [expterm1, expterm2, ...]}

# %%
expterms_path = '../data/robust/expansion_terms/'

# %%
ceqe_maxpool = queries_exp_terms_list_to_dict(json.load(open(expterms_path+'bm25.ceqe-maxpool.pretrained.json')))

# %%
rm3_exp_terms = queries_exp_terms_list_to_dict(json.load(open(expterms_path+'bm25.rm3.json')))

# %%
len(ceqe_maxpool.keys())
# Out:
# 250

# %%
len(rm3_exp_terms)
# Out:
# 250

# %% [markdown]
# ### Print the difference between expansion terms

# %%
diff_ceqeMaxpool_rm3 = get_method_diff(ceqe_maxpool, rm3_exp_terms, topk=20)

# %%
for q_id in queries:
    print(q_id, queries[q_id])
    print("Expansion terms only in rm3: ",diff_ceqeMaxpool_rm3[q_id]['diff_terms']['method1_ex_2'])
    print("Expansion terms only in Glove", diff_ceqeMaxpool_rm3[q_id]['diff_terms']['method2_ex_1'])
    print('---'*10)
# Out:
# 301 international organized crime
# Expansion terms only in rm3:  {'1993', 'europe', 'crimes', 'intelligence', 'world', 'east'}
# Expansion terms only in Glove {'states', 'cooperation', 'economic', 'control', 'new', 'interior'}
# ------------------------------
# 302 poliomyelitis post polio
# Expansion terms only in rm3:  {'problems', 'ipv', 'immunization', 'opv', 'person', 'china', 'people', 'million', 'year'}
# Expansion terms only in Glove {'declining', 'hemisphere', 'states', 'areas', 'programme', 'mass', 'cent', 'gujarat', 'annually'}
# ------------------------------
# 303 hubble telescope achievements
# Expansion terms only in rm3:  {'flight', 'optical', 'astronauts', 'hubbles', 'mirrors', 'telescopes'}
# Expansion terms only in Glove {'two', 'april', 'batteries', 'three', 'new', 'years'}
# ------------------------------
# 304 endangered species mammals
# Expansion terms only in rm3:  {'regulations', 'mammal', 'resources', 'fish', 'information', 'protected'}
# Expansion terms only in Glove {'take', 'taking', 'request', 'notice', 'sea', '2'}
# ------------------------------
# 305 most dangerous vehicles
# Expansion terms only in rm3:  {'weapons', 'car', 'accidents', 'road', 'fleet', 'vehicle', 'operations'}
# Expansion terms only in Glove {'nuclear', 'two', 'minister', 'video', 'time', 'new', 'test'}
# ------------------------------
# 306 african civilian deaths
# Expansion terms only in rm3:  {'black', 'mr', 'army', 'civilians', 'human', 'death', 'africa'}
# Expansion terms only in Glove {'kigali', 'security', 'un', '1', 'force', 'war', 'rebels'}
# ------------------------------
# 307 new hydroelectric projects
# Expansion terms only in rm3:  {'facilities', 'construction', 'electric', 'electricity', 'powerhouse', 'nuclear', 'generator', 'energy', 'plant', 'vietnam', 'project', 'existing'}
# Expansion terms only in Glove {'contact', 'federal', 'long', 'application', 'notice', 'applicant', 'b', '2', '16', 'development', 'date', 'feet'}
# ------------------------------
# 308 implant dentistry
# Expansion terms only in rm3:  {'psychology', 'univ', 'college', 'june', '1988', 'ca', '1987', 'device', 'clg', 'med', 'implants', 'university', 'osteopathy', 'medicine', 'chiropractic', 'podiatry', 'allopathic'}
# Expansion terms only in Glove {'success', 'teeth', 'treatment', 'school', 'training', 'dentist', 'dentists', 'manufacturers', 'center', 'antibiotic', 'special', '10', 'dr', 'gum', 'fda', 'says', 'years'}
# ------------------------------
# 309 rap crime
# Expansion terms only in rm3:  {'recreation', 'records', 'merseyside', 'mr', 'image', 'record', 'gay', 'rapper', 'raps', 'health'}
# Expansion terms only in Glove {'show', 'edition', 'dont', 'home', 'angeles', 'two', 'white', 'new', 'los', 'enemy'}
# ------------------------------
# 310 radio waves brain cancer
# Expansion terms only in rm3:  {'fields', 'cholesterol', 'blood', 'patients', 'radiation', 'gene', 'electromagnetic', 'studies', 'body', 'therapy', 'disease', 'power', 'immune'}
# Expansion terms only in Glove {'motorola', 'companies', 'dollars', 'phone', 'phones', 'public', 'industry', 'magnetic', 'yesterday', 'cent', 'evidence', 'new', 'scare'}
# ------------------------------
# 311 industrial espionage
# Expansion terms only in rm3:  {'documents', 'director', 'mr', 'production', 'secrets'}
# Expansion terms only in Glove {'foreign', 'yesterday', 'two', 'former', 'new'}
# ------------------------------
# 312 hydroponics
# Expansion terms only in rm3:  {'bib', 'farm', 'project', 'system', 'hydroponic', 'year', 'agriculture', 'grown'}
# Expansion terms only in Glove {'ncis', 'skunk', 'form', 'police', 'cent', 'seizures', 'steroid', '2'}
# ------------------------------
# 313 magnetic levitation maglev
# Expansion terms only in rm3:  {'bechtel', 'transrapid', 'car', 'force', 'material'}
# Expansion terms only in Glove {'noise', 'cars', 'track', 'test', 'development'}
# ------------------------------
# 314 marine vegetation
# Expansion terms only in rm3:  {'bay', 'island', 'ocean', 'national', 'coastal', 'sea', 'management', 'wildlife'}
# Expansion terms only in Glove {'3', 'st', 'napa', 'memorial', '30', 'floor', '2', 'santa'}
# ------------------------------
# 315 unexplained highway accidents
# Expansion terms only in rm3:  {'stretch', 'state', 'valley', 'siordia', 'railroad', 'safety', 'rail', 'chp', 'vehicles', 'people', 'cars', 'car', 'accident', 'lanes'}
# Expansion terms only in Glove {'angle', 'fra', 'velocity', 'make', 'tilt', 'two', 'percent', 'critical', 'sliding', 'table', 'models', 'rollover', 'model', 'driver'}
# ------------------------------
# 316 polygamy polyandry polygyny
# Expansion terms only in rm3:  {'support', 'party', 'life', 'birth', 'growth', 'tebbit', 'sexual', 'lebaron', 'year'}
# Expansion terms only in Glove {'marriage', 'two', 'people', '00', 'three', 'part', 'c4', 'nine', 'years'}
# ------------------------------
# 317 unsolicited faxes
# Expansion terms only in rm3:  {'documents', 'printed', 'customer', 'mr', 'proposed', 'customers', 'office', 'faxed', 'pc', 'suitability', 'send', 'information', 'paper', 'rule'}
# Expansion terms only in Glove {'message', 'bill', 'legislation', 'phone', 'dont', 'auto', '000', '1', 'house', 'president', 'dialing', 'businesses', 'junk', 'hospital'}
# ------------------------------
# 318 best retirement country
# Expansion terms only in rm3:  {'retire', 'work', 'home', 'countries', 'year', 'retired'}
# Expansion terms only in Glove {'government', 'two', 'old', 'social', 'new', '65'}
# ------------------------------
# 319 new fuel sources
# Expansion terms only in rm3:  {'air', 'source', 'spent', 'sulfur', 'emission', 'material', 'fuels'}
# Expansion terms only in Glove {'5', '3', 'percent', '6', 'system', '10', '7'}
# ------------------------------
# 320 undersea fiber optic cable
# Expansion terms only in rm3:  {'fibre', 'fibers', 'wavelength', 'cables', 'systems', 'dispersion', 'transmission'}
# Expansion terms only in Glove {'cfr', '1', 'international', 'company', 'services', 'sprint', 'soviet'}
# ------------------------------
# 321 women parliaments
# Expansion terms only in rm3:  {'members', 'male', 'men', 'mrs', 'ms', 'parliament', 'woman', 'elected', 'labours', 'womens'}
# Expansion terms only in Glove {'election', 'new', 'church', 'today', 'shadow', 'number', 'ft', 'three', 'vote', 'cabinet'}
# ------------------------------
# 322 international art crime
# Expansion terms only in rm3:  {'paintings', 'support', 'antiques', 'coalition', 'public', 'italian', 'arts', 'world', 'year', 'culture', 'istanbul'}
# Expansion terms only in Glove {'criminal', 'security', 'home', '000', 'people', 'two', 'time', 'million', 'drug', 'new', 'years'}
# ------------------------------
# 323 literary journalistic plagiarism
# Expansion terms only in rm3:  {'journalists', 'duffin', 'edition', 'press', 'life', 'people', 'university', 'world', 'great', 'american', 'wolfe'}
# Expansion terms only in Glove {'stolen', 'mallons', 'holmes', 'two', 'novel', 'time', 'point', 'love', 'mallon', 'coleridge', 'ones'}
# ------------------------------
# 324 argentine british relations
# Expansion terms only in rm3:  {'clarin', 'chile', 'malvinas', 'argentina', 'britain', 'visit'}
# Expansion terms only in Glove {'military', '1982', 'oil', 'two', 'issue', 'countries'}
# ------------------------------
# 325 cult lifestyles
# Expansion terms only in rm3:  {'groups', 'children', 'left', 'students', 'mr', 'suicide', 'mass', 'activities', 'group', 'followers', 'compound', 'campus', 'fbi', 'cults', 'agents'}
# Expansion terms only in Glove {'chilton', 'late', 'uk', 'trust', 'krishna', 'mother', 'two', 'car', 'david', 'tax', 'new', 'kim', 'hare', 'band', 'diana'}
# ------------------------------
# 326 ferry sinkings
# Expansion terms only in rm3:  {'vessels', 'mr', 'vessel', 'shipping', 'vehicle', 'ferries', 'sinking'}
# Expansion terms only in Glove {'baltic', 'yesterday', 'ft', 'lives', 'standards', '94', 'international'}
# ------------------------------
# 327 modern slavery
# Expansion terms only in rm3:  {'children', 'society', 'murder', 'work', 'america', 'today', 'blacks', 'development', 'decision'}
# Expansion terms only in Glove {'indias', 'gandhi', 'indian', 'national', 'time', 'independence', 'arvind', 'new', 'west'}
# ------------------------------
# 328 pope beatifications
# Expansion terms only in rm3:  {'pontiff', 'msgr', 'beatified', 'popes', 'miracle', 'governor', 'beatification', 'sainthood', 'mission'}
# Expansion terms only in Glove {'movement', 'members', 'process', 'time', 'cause', 'ii', 'de', 'sponsors', 'years'}
# ------------------------------
# 329 mexican air pollution
# Expansion terms only in rm3:  {'mr', 'mexicos', 'manuel', 'water', 'environment', 'mexico'}
# Expansion terms only in Glove {'levels', 'reports', 'dollars', 'japanese', 'help', 'new'}
# ------------------------------
# 330 iran iraq cooperation
# Expansion terms only in rm3:  {'irans', 'iraqi', 'islamic', 'iranian', 'rafsanjani'}
# Expansion terms only in Glove {'two', 'officials', 'issue', 'united', 'international'}
# ------------------------------
# 331 world bank criticism
# Expansion terms only in rm3:  {'mr', 'financial', 'central', 'banks', 'imf', 'finance', 'international'}
# Expansion terms only in Glove {'set', 'morse', 'former', 'ft', 'new', 'plan', 'treasury'}
# ------------------------------
# 332 income tax evasion
# Expansion terms only in rm3:  {'mr', 'economic', 'fiscal', 'year', 'taxes'}
# Expansion terms only in Glove {'30', 'prosecutors', 'new', 'yuan', 'rmb'}
# ------------------------------
# 333 antibiotics bacteria disease
# Expansion terms only in rm3:  {'treatment', 'diseases', 'activity', 'antibiotic', 'strains', 'year', 'virus'}
# Expansion terms only in Glove {'infectious', 'resistant', 'india', 'world', 'cause', 'new', 'severe'}
# ------------------------------
# 334 export controls cryptography
# Expansion terms only in rm3:  {'signature', 'processing', 'encryption', 'cryptographic', 'agency'}
# Expansion terms only in Glove {'module', 'calls', 'nist', 'service', '140'}
# ------------------------------
# 335 adoptive biological parents
# Expansion terms only in rm3:  {'adoptees', 'custody', 'people', 'case', 'genetic', 'open', 'parent'}
# Expansion terms only in Glove {'designed', 'care', 'programs', 'foster', 'time', 'old', 'sabol'}
# ------------------------------
# 336 black bear attacks
# Expansion terms only in rm3:  {'lynx', 'coyotes', 'listing', 'people', 'south', 'deer', 'blind', 'including', 'bears', 'ungulates', 'wolves'}
# Expansion terms only in Glove {'dec', 'sept', 'nov', 'feb', 'two', 'aug', '30', 'b', '10', 'unit', '31'}
# ------------------------------
# 337 viral hepatitis
# Expansion terms only in rm3:  {'infectious', 'condition', 'bfn', 'epidemic', 'diseases', 'transmitted', 'blood', 'infections', 'people', 'liver', 'article', 'cases', 'type', 'year', 'virus', 'hospital'}
# Expansion terms only in Glove {'unspecified', '387', '3891', '07', 'mention', 'hepatic', 'y', '070', '130', 'n', 'b', '205', '206', '05', '15', 'coma'}
# ------------------------------
# 338 risk aspirin
# Expansion terms only in rm3:  {'researchers', 'taking', 'effective', 'ticlopidine', 'found', 'warfarin', 'quinine'}
# Expansion terms only in Glove {'take', 'attack', '000', 'half', 'new', 'health', 'women'}
# ------------------------------
# 339 alzheimers drug treatment
# Expansion terms only in rm3:  {'drugs', 'mr', 'clinical', 'sufferers', 'year', 'tacrine', 'medicine', 'pharmaceuticals'}
# Expansion terms only in Glove {'years', 'dollars', 'warner', 'found', 'new', 'hydergine', 'lambert', 'placebo'}
# ------------------------------
# 340 land mine ban
# Expansion terms only in rm3:  {'bfn', 'asbestos', 'export', 'industry', 'million', 'development', 'landmines', 'waste', 'mines'}
# Expansion terms only in Glove {'cambodia', 'dollars', 'ranariddh', 'western', 'un', 'meeting', 'world', 'group', 'self'}
# ------------------------------
# 341 airport security
# Expansion terms only in rm3:  {'carriers', 'flight', 'aircraft', 'airline', 'airports', 'civil', 'passenger', 'international'}
# Expansion terms only in Glove {'two', 'systems', 'terrorist', 'people', 'officials', 'committee', 'flights', 'new'}
# ------------------------------
# 342 diplomatic expulsion
# Expansion terms only in rm3:  {'diplomat', 'mr', 'expulsions', 'office', 'ambassador'}
# Expansion terms only in Glove {'moscow', 'norway', 'two', 'norwegian', 'iran'}
# ------------------------------
# 343 police deaths
# Expansion terms only in rm3:  {'santos', 'detectives', 'injuries', 'murder', 'arrested', 'deputies', 'death', 'car', 'shot', 'violence', 'year', 'taser'}
# Expansion terms only in Glove {'county', 'angeles', 'two', 'case', 'number', 'time', 'three', 'old', 'department', 'los', 'williams', 'years'}
# ------------------------------
# 344 abuses e mail
# Expansion terms only in rm3:  {'abuse', 'subpart', 'report', 'programs', 'security', 'service', '2'}
# Expansion terms only in Glove {'2680', 'diego', 'act', '28', 'shall', 'section', 'usc'}
# ------------------------------
# 345 overseas tobacco sales
# Expansion terms only in rm3:  {'smoking', 'food', 'year', 'business', 'morris'}
# Expansion terms only in Glove {'nabisco', 'income', 'quarter', 'japan', 'new'}
# ------------------------------
# 346 educational standards
# Expansion terms only in rm3:  {'standard', 'requirements', 'school', 'training'}
# Expansion terms only in Glove {'2', 'title', 'section', 'b'}
# ------------------------------
# 347 wildlife extinction
# Expansion terms only in rm3:  {'animals', 'recovery', 'edition', 'people', 'shrimp', 'bears', 'years'}
# Expansion terms only in Glove {'final', 'federal', 'public', 'act', '1994', 'rule', 'plants'}
# ------------------------------
# 348 agoraphobia
# Expansion terms only in rm3:  {'mental', 'pharos', 'center', 'cartoonists', 'love', 'depression', 'health'}
# Expansion terms only in Glove {'school', 'artist', 'world', '2', 'haired', 'red', 'says'}
# ------------------------------
# 349 metabolism
# Expansion terms only in rm3:  {'chemicals', 'toxicity', 'testing', 'sales', 'chemical', 'weight', 'rate', 'brain'}
# Expansion terms only in Glove {'nicotine', 'smokers', 'constituents', 'smoke', 'system', 'cotinine', 'ex', 'nonsmokers'}
# ------------------------------
# 350 health computer terminals
# Expansion terms only in rm3:  {'care', 'records', 'terminal', 'products', 'computers', 'research', 'services'}
# Expansion terms only in Glove {'injuries', 'study', 'vdt', 'two', 'occupational', 'new', 'bee'}
# ------------------------------
# 351 falkland petroleum exploration
# Expansion terms only in rm3:  {'falklands', 'mr', 'year', 'argentinas'}
# Expansion terms only in Glove {'sovereignty', 'feb', 'disputed', 'ft'}
# ------------------------------
# 352 british chunnel impact
# Expansion terms only in rm3:  {'terminal', 'life', 'jack', 'business', '94'}
# Expansion terms only in Glove {'two', '000', 'eurotunnel', 'pounds', 'sector'}
# ------------------------------
# 353 antarctica exploration
# Expansion terms only in rm3:  {'scientists', 'tourists', 'polar', 'scientific', 'antarcticas', 'research', 'station', 'chile', 'south', 'ice', 'pole'}
# Expansion terms only in Glove {'minerals', 'agreement', '20', 'treaty', 'nations', 'conference', 'oil', 'time', 'greenpeace', 'future', 'extraction'}
# ------------------------------
# 354 journalist risks
# Expansion terms only in rm3:  {'journalists', 'recording', 'programme', 'killed', 'public', 'article', 'risk', 'freedom', 'area', 'bfn'}
# Expansion terms only in Glove {'rsi', 'take', 'reported', 'newspapers', 'police', 'two', 'news', 'case', 'new', 'says'}
# ------------------------------
# 355 ocean remote sensing
# Expansion terms only in rm3:  {'naval', 'system', 'lake', 'environmental', 'international'}
# Expansion terms only in Glove {'microwave', 'radio', 'monitoring', '2', 'years'}
# ------------------------------
# 356 postmenopausal estrogen britain
# Expansion terms only in rm3:  {'menopausal', 'osteoporosis', 'edition', 'vaginal', 'dr', 'years'}
# Expansion terms only in Glove {'taking', 'heart', 'university', 'medical', 'says', 'participants'}
# ------------------------------
# 357 territorial waters dispute
# Expansion terms only in rm3:  {'disputes', 'fishermen', 'government', 'disputed', 'fisheries', 'mile'}
# Expansion terms only in Glove {'contract', 'vietnamese', 'chinese', 'japan', 'ministry', 'corporation'}
# ------------------------------
# 358 blood alcohol fatalities
# Expansion terms only in rm3:  {'county', 'drugs', 'killed', 'traffic', 'total', 'year', 'drug', 'impaired', 'died', 'cocaine'}
# Expansion terms only in Glove {'study', 'california', '12', '04', 'two', 'lbs', '08', 'law', 'new', '05'}
# ------------------------------
# 359 mutual fund predictors
# Expansion terms only in rm3:  {'markets', 'shares', 'banks', 'securities', 'company'}
# Expansion terms only in Glove {'dollars', '1', 'cent', 'dreyfus', 'says'}
# ------------------------------
# 360 drug legalization benefits
# Expansion terms only in rm3:  {'drugs', 'treatment', 'continue', 'bedout', 'alcohol', 'kendall', 'crime', 'jauvert', 'surrender'}
# Expansion terms only in Glove {'state', 'believe', 'people', 'countries', 'bennett', 'problem', 'new', 'crack', 'years'}
# ------------------------------
# 361 clothing sweatshops
# Expansion terms only in rm3:  {'abuses', 'hour', 'sweatshop'}
# Expansion terms only in Glove {'new', 'orange', 'law'}
# ------------------------------
# 362 human smuggling
# Expansion terms only in rm3:  {'fight', 'irans', 'emigration', 'activities', 'people', 'cargo', 'law', 'smugglers'}
# Expansion terms only in Glove {'rights', 'states', 'fujian', 'government', 'two', '000', 'country', 'united'}
# ------------------------------
# 363 transportation tunnel disasters
# Expansion terms only in rm3:  {'disaster', 'distribution', 'tunnels', 'bridge', 'transport', 'construction', 'city', 'traffic', 'hainan', 'railway', 'infrastructure', 'companies'}
# Expansion terms only in Glove {'workers', 'trading', 'work', 'cut', 'fire', 'cme', 'freeway', 'new', 'area', 'business', 'declared', 'second'}
# ------------------------------
# 364 rabies
# Expansion terms only in rm3:  {'cows', 'infected', 'vaccinated', 'year'}
# Expansion terms only in Glove {'administration', 'state', 'aphis', 'disease'}
# ------------------------------
# 365 el nino
# Expansion terms only in rm3:  {'effect', 'peruvian', 'storms', 'year'}
# Expansion terms only in Glove {'south', 'cent', 'say', 'degrees'}
# ------------------------------
# 366 commercial cyanide uses
# Expansion terms only in rm3:  {'hazardous', 'mining', 'sodium', 'fruit'}
# Expansion terms only in Glove {'sub', 'process', 'wastewater', 'l'}
# ------------------------------
# 367 piracy
# Expansion terms only in rm3:  {'sold', 'pirates', 'news', 'pirate', 'year', 'lost'}
# Expansion terms only in Glove {'bsa', 'anti', 'cent', 'chinese', 'says', 'international'}
# ------------------------------
# 368 vitro fertilization
# Expansion terms only in rm3:  {'children', 'fertilized', 'mother', 'life', 'child', 'pregnancy', 'ivf', 'test', 'couples'}
# Expansion terms only in Glove {'tube', 'edition', 'couple', 'womans', 'fallopian', 'old', 'werlin', 'born', 'hospital'}
# ------------------------------
# 369 anorexia nervosa bulimia
# Expansion terms only in rm3:  {'years', 'ager', 'euphoria', 'anorexics', 'time', 'problem', 'company', 'tobacco', 'women'}
# Expansion terms only in Glove {'study', 'research', 'discovered', 'university', 'say', 'american', 'high', 'hunger', 'given'}
# ------------------------------
# 370 food drug laws
# Expansion terms only in rm3:  {'regulations', 'drugs', 'authority', 'debarment', 'law', 'labeling'}
# Expansion terms only in Glove {'cfr', 'public', 'dr', '2', 'usc', '1994'}
# ------------------------------
# 371 health insurance holistic
# Expansion terms only in rm3:  {'support', 'programs', 'cellular', 'prevention', 'develops', 'child', 'coordination', 'service', 'control', 'family'}
# Expansion terms only in Glove {'county', 'government', 'two', '000', 'time', 'johnson', 'new', 'pounds', 'development', 'enright'}
# ------------------------------
# 372 native american casino
# Expansion terms only in rm3:  {'state', 'indians', 'world', 'north', 'year', 'reservation', 'circus', 'casinos'}
# Expansion terms only in Glove {'leaders', '3', '8', '1', 'cent', 'president', 'white', 'new'}
# ------------------------------
# 373 encryption equipment export
# Expansion terms only in rm3:  {'modules', 'telecommunications', 'requirements', 'internet'}
# Expansion terms only in Glove {'digital', 'government', 'networks', 'clipper'}
# ------------------------------
# 374 nobel prize winners
# Expansion terms only in rm3:  {'prime', 'winner', 'scientific', 'research', 'minister', 'prizes', 'awarded'}
# Expansion terms only in Glove {'years', 'two', 'committee', 'world', 'new', 'academy', 'cas'}
# ------------------------------
# 375 hydrogen energy
# Expansion terms only in rm3:  {'production', 'produced', 'carbon'}
# Expansion terms only in Glove {'new', 'air', 'japanese'}
# ------------------------------
# 376 world court
# Expansion terms only in rm3:  {'disputes', 'courts', 'final', 'state', 'wimbledon', 'russian', 'intellectual', 'human', 'property', 'tennis', 'federation'}
# Expansion terms only in Glove {'appeals', 'foreign', 'government', 'un', 'two', 'amd', 'case', 'bbc', 'service', 'new', 'intel'}
# ------------------------------
# 377 cigar smoking
# Expansion terms only in rm3:  {'day', '1989', 'ban', 'american', 'tax', 'cigars', 'cigarette'}
# Expansion terms only in Glove {'two', 'people', 'castro', 'didnt', 'president', 'new', 'usc'}
# ------------------------------
# 378 euro opposition
# Expansion terms only in rm3:  {'mr', 'ratification'}
# Expansion terms only in Glove {'john', 'commons'}
# ------------------------------
# 379 mainstreaming
# Expansion terms only in rm3:  {'leadership', 'valley', 'mr', 'mainstream', 'system', 'engineering'}
# Expansion terms only in Glove {'right', 'two', 'based', 'three', '92', 'mps'}
# ------------------------------
# 380 obesity medical treatment
# Expansion terms only in rm3:  {'clinics', 'overweight', 'programs', 'program', 'studies', 'benefit', 'plan', 'healthcare'}
# Expansion terms only in Glove {'levels', 'cholesterol', 'blood', 'risk', 'high', 'claim', 'drugs', 'new'}
# ------------------------------
# 381 alternative medicine
# Expansion terms only in rm3:  {'care', 'nih', 'physicians', 'research', 'government', 'high', 'medicines', 'prescription'}
# Expansion terms only in Glove {'full', '8', '1', 'council', '30', 'pm', 'subcommittees', '1994'}
# ------------------------------
# 382 hydrogen fuel automobiles
# Expansion terms only in rm3:  {'automobile', 'dual', 'car', 'fueled', 'passenger', 'fuels', 'vehicle'}
# Expansion terms only in Glove {'efficiency', 'nhtsa', 'economy', '1', 'methanol', 'minimum', 'power'}
# ------------------------------
# 383 mental illness drugs
# Expansion terms only in rm3:  {'disorders', 'suicide', 'emotional', 'drug', 'substance', 'hospital'}
# Expansion terms only in Glove {'children', 'programs', 'people', 'cent', 'shall', 'says'}
# ------------------------------
# 384 space station moon
# Expansion terms only in rm3:  {'launch', 'soyuz', 'exploration', 'orbit', 'astronauts', 'rocket', 'surface'}
# Expansion terms only in Glove {'armstrong', 'back', 'report', 'time', 'budget', 'new', 'aldrin'}
# ------------------------------
# 385 hybrid fuel cars
# Expansion terms only in rm3:  {'fueled', 'buses', 'car', 'driving'}
# Expansion terms only in Glove {'new', 'based', 'project', 'ford'}
# ------------------------------
# 386 teaching disabled children
# Expansion terms only in rm3:  {'kids', 'schools', 'handicapped', 'people', 'reading', 'year'}
# Expansion terms only in Glove {'state', 'buckey', '1', 'old', 'help', 'says'}
# ------------------------------
# 387 radioactive waste
# Expansion terms only in rm3:  {'radiation', 'site', 'wastes', 'environmental', 'dumping'}
# Expansion terms only in Glove {'non', '3', 'capacity', 'national', 'high'}
# ------------------------------
# 388 organic soil enhancement
# Expansion terms only in rm3:  {'radioactive', 'soils', 'land'}
# Expansion terms only in Glove {'research', 'technologies', 'technology'}
# ------------------------------
# 389 illegal technology transfer
# Expansion terms only in rm3:  {'trade', 'export', 'illegally', 'dealers', 'trafficking'}
# Expansion terms only in Glove {'thailand', 'london', 'isc', 'ministry', 'ferranti'}
# ------------------------------
# 390 orphan drugs
# Expansion terms only in rm3:  {'care', 'children', 'disorders', 'amgen', 'drug', 'home', 'year'}
# Expansion terms only in Glove {'grant', 'legislation', 'act', 'bush', 'new', 'health', 'fda'}
# ------------------------------
# 391 rd drug prices
# Expansion terms only in rm3:  {'tablets', 'po', 'clinical'}
# Expansion terms only in Glove {'smithkline', 'blvd', '1'}
# ------------------------------
# 392 robotics
# Expansion terms only in rm3:  {'manufacturing', 'production', 'installed', 'robots', 'systems', 'automotive', 'year', 'robot', 'vehicle'}
# Expansion terms only in Glove {'sales', 'two', 'europe', 'japanese', 'cent', 'european', 'new', 'market', 'says'}
# ------------------------------
# 393 mercy killing
# Expansion terms only in rm3:  {'final', 'killed', 'convicted', 'sentence', 'jury', 'williams', 'sentenced'}
# Expansion terms only in Glove {'religious', 'san', 'right', 'two', 'three', 'medical', 'die'}
# ------------------------------
# 394 home schooling
# Expansion terms only in rm3:  {'areas', 'language', 'round', 'teaching', 'year'}
# Expansion terms only in Glove {'state', 'work', 'government', 'self', 'new'}
# ------------------------------
# 395 tourism
# Expansion terms only in rm3:  {'commerce', 'mr', 'promotion', 'government', 'year'}
# Expansion terms only in Glove {'public', 'committee', 'world', 'new', 'market'}
# ------------------------------
# 396 sick building syndrome
# Expansion terms only in rm3:  {'tobacco', 'buildings', 'smoke', 'problems'}
# Expansion terms only in Glove {'cause', 'research', '3', 'hse'}
# ------------------------------
# 397 automobile recalls
# Expansion terms only in rm3:  {'imports', 'automobiles', 'toyota', '000', 'industry', 'diesel', 'recalled'}
# Expansion terms only in Glove {'states', 'vehicles', '1', 'talks', 'gm', 'new', 'vehicle'}
# ------------------------------
# 398 dismantling europes arsenal
# Expansion terms only in rm3:  {'mr', 'dismantle', 'europe', 'uranium', 'european', 'countries'}
# Expansion terms only in Glove {'clinton', 'former', 'new', 'united', 'kiev', 'start'}
# ------------------------------
# 399 oceanographic vessels
# Expansion terms only in rm3:  {'scientists', 'ship', 'russian', 'navy', 'survey', 'vessel', 'oceanography', 'sea', 'japan', 'institute', 'okean', 'seabed'}
# Expansion terms only in Glove {'states', 'director', 'scripps', 'chief', 'safety', 'united', 'office', 'university', 'data', 'section', 'new', 'administration'}
# ------------------------------
# 400 amazon rain forest
# Expansion terms only in rm3:  {'state', 'brazils', 'peru', 'amazonia', 'basin', 'tropical', 'jungle', 'forests'}
# Expansion terms only in Glove {'murder', '1989', 'people', 'ranchers', 'japan', 'kasten', 'trees', 'road'}
# ------------------------------
# 401 foreign minorities germany
# Expansion terms only in rm3:  {'minority', 'german', 'germans', 'mr'}
# Expansion terms only in Glove {'meeting', 'conference', 'new', 'voting'}
# ------------------------------
# 402 behavioral genetics
# Expansion terms only in rm3:  {'md', 'behavior', 'review', 'human', 'sciences', 'inn', 'institute', 'holiday', 'health', 'disease', 'hotel'}
# Expansion terms only in Glove {'researchers', 'twins', 'two', 'people', 'parents', 'child', 'time', 'environment', '30', 'minnesota', 'new'}
# ------------------------------
# 403 osteoporosis
# Expansion terms only in rm3:  {'researchers', 'treatment', '1', 'developing', 'fat'}
# Expansion terms only in Glove {'peak', 'study', 'rate', 'adequate', 'shall'}
# ------------------------------
# 404 ireland peace talks
# Expansion terms only in rm3:  {'irish', 'mr', 'initiative', 'john', 'adams', 'patrick'}
# Expansion terms only in Glove {'yesterday', 'declaration', 'minister', 'british', 'violence', 'governments'}
# ------------------------------
# 405 cosmic events
# Expansion terms only in rm3:  {'big', 'scientists', 'event', 'bang', 'matter', '1', 'galactic', 'dust', 'years'}
# Expansion terms only in Glove {'russian', 'interplanetary', 'magnitude', 'fluxes', 'magnetic', 'type', 'fluence', 'earths', 'proton'}
# ------------------------------
# 406 parkinsons disease
# Expansion terms only in rm3:  {'diseases', 'transplants', 'degenerative', 'human', 'neurological', 'health'}
# Expansion terms only in Glove {'study', 'new', 'deprenyl', '000', 'cause', 'victims'}
# ------------------------------
# 407 poaching wildlife preserves
# Expansion terms only in rm3:  {'musk', 'mr', 'poachers', 'police', 'rhino', 'wild', 'endangered', 'horns'}
# Expansion terms only in Glove {'local', 'kenya', 'international', 'national', 'kenyas', 'tourism', 'says', 'leakey'}
# ------------------------------
# 408 tropical storms
# Expansion terms only in rm3:  {'storm', 'weather', 'coastal', 'eastern', 'islands', 'weakens'}
# Expansion terms only in Glove {'miles', 'saturday', '1', 'coast', 'sunday', 'expected'}
# ------------------------------
# 409 legal pan am 103
# Expansion terms only in rm3:  {'edition', 'airways', 'group', 'case'}
# Expansion terms only in Glove {'york', 'jet', 'new', '21'}
# ------------------------------
# 410 schengen agreement
# Expansion terms only in rm3:  {'germany', 'portugal', 'community', 'treaty', 'britain'}
# Expansion terms only in Glove {'passport', 'committee', 'information', 'executive', 'nine'}
# ------------------------------
# 411 salvaging shipwreck treasure
# Expansion terms only in rm3:  {'marine', 'director', 'permit', 'resources', 'ocean', 'whisky', 'activity', '93', 'salvage', 'news', 'salvaged', 'galore', 'cultural', 'sanctuary'}
# Expansion terms only in Glove {'state', 'humphreys', 'dollars', 'find', 'value', 'two', '000', 'bars', 'water', 'three', 'coin', 'coins', 'maravillas', 'years'}
# ------------------------------
# 412 airport security
# Expansion terms only in rm3:  {'terminal', 'flight', 'aircraft', 'airline', 'airports', 'passenger'}
# Expansion terms only in Glove {'two', 'committee', 'metal', 'night', 'new', 'area'}
# ------------------------------
# 413 steel production
# Expansion terms only in rm3:  {'output', 'makers', 'consumption', 'metal', 'year', 'crude', 'steelmakers'}
# Expansion terms only in Glove {'products', 'percent', 'period', 'million', 'company', 'pig', 'market'}
# ------------------------------
# 414 cuba sugar exports
# Expansion terms only in rm3:  {'cubas', 'mr', 'export', 'industry', 'cuban', 'year', 'agriculture'}
# Expansion terms only in Glove {'cane', 'state', 'union', 'foreign', 'economic', 'cent', 'russia'}
# ------------------------------
# 415 drugs golden triangle
# Expansion terms only in rm3:  {'states', 'fight', 'chinese', 'drug', 'seized', 'area'}
# Expansion terms only in Glove {'state', 'thai', 'government', 'un', 'sa', 'burma'}
# ------------------------------
# 416 three gorges project
# Expansion terms only in rm3:  {'river', 'projects'}
# Expansion terms only in Glove {'areas', 'peng'}
# ------------------------------
# 417 creativity
# Expansion terms only in rm3:  {'scientists', 'society', 'experts', 'community', 'make', 'shanghai', 'development'}
# Expansion terms only in Glove {'mental', 'home', 'says', 'ideas', 'university', 'new', 'way'}
# ------------------------------
# 418 quilts income
# Expansion terms only in rm3:  {'quilt', 'moves', 'quilting', 'quilters', 'baines', 'sharp', 'quilter', 'goodisons'}
# Expansion terms only in Glove {'show', 'county', 'memorial', 'chairman', 'make', 'cent', 'american', 'says'}
# ------------------------------
# 419 recycle automobile tires
# Expansion terms only in rm3:  {'efficiency', 'parts', 'tire', 'electric', 'cars', 'water', 'car', 'energy', 'recycling', 'items', 'year', 'vehicle'}
# Expansion terms only in Glove {'network', 'firm', 'percent', 'european', 'peugeot', 'system', 'shall', '10', 'plant', 'new', 'renault', 'waste'}
# ------------------------------
# 420 carbon monoxide poisoning
# Expansion terms only in rm3:  {'house', 'thursday', 'fumes', '1989'}
# Expansion terms only in Glove {'manoguerra', 'system', 'center', 'medical'}
# ------------------------------
# 421 industrial waste disposal
# Expansion terms only in rm3:  {'toxic', 'municipal', 'pollution', 'products', 'chemical', 'site', 'packaging', 'environment', 'wastes', 'recycling', 'environmental'}
# Expansion terms only in Glove {'nrs', 'nac', 'c', '002', 'china', 'oar', '340', 'co', '1992', '100', '444'}
# ------------------------------
# 422 art stolen forged
# Expansion terms only in rm3:  {'paintings', 'thieves', 'major', 'collection', 'money', 'cars', 'property', 'items', 'year'}
# Expansion terms only in Glove {'least', 'angeles', 'two', 'security', 'ventura', '1', 'million', 'sothebys', 'los'}
# ------------------------------
# 423 milosevic mirjana markovic
# Expansion terms only in rm3:  {'mr', 'slobodan', 'yugoslavia', 'seselj', 'dafina', 'croatia', 'milosevics', 'milanovic'}
# Expansion terms only in Glove {'opposition', 'media', 'television', 'people', 'political', 'minister', 'bank', 'war'}
# ------------------------------
# 424 suicides
# Expansion terms only in rm3:  {'suicide', 'attacks', 'disorder', 'bars', 'group', 'risk', 'attempt', 'youth', 'year', 'victims', 'depressed', 'living'}
# Expansion terms only in Glove {'religious', 'new', 'adkins', 'life', 'two', 'case', 'number', 'three', 'medical', '4', 'kevorkian', 'health'}
# ------------------------------
# 425 counterfeiting money
# Expansion terms only in rm3:  {'cash', 'counterfeiters', 'million', 'counterfeit', 'sources', 'year', 'printing'}
# Expansion terms only in Glove {'state', 'two', 'vienna', 'zhao', 'campus', 'sun', 'yuan'}
# ------------------------------
# 426 law enforcement dogs
# Expansion terms only in rm3:  {'officer', 'officers', 'service', 'animal', 'agencies', 'laws'}
# Expansion terms only in Glove {'san', 'pit', 'two', 'ban', 'diego', 'say'}
# ------------------------------
# 427 uv damage eyes
# Expansion terms only in rm3:  {'room', 'cm', 'air', 'sun'}
# Expansion terms only in Glove {'parents', 'comment', 'says', '1'}
# ------------------------------
# 428 declining birth rates
# Expansion terms only in rm3:  {'age', 'rate', 'decline', 'year', 'births', 'demographic', 'born'}
# Expansion terms only in Glove {'1986', 'mortality', '000', '1', 'deaths', '1992', '2'}
# ------------------------------
# 429 legionnaires disease
# Expansion terms only in rm3:  {'illness', 'cooling', 'respiratory', 'bacteria', 'transmission'}
# Expansion terms only in Glove {'j', 'b', '2', 'pneumophila', 'hospital'}
# ------------------------------
# 430 killer bee attacks
# Expansion terms only in rm3:  {'stung', 'victim', 'escape', 'bees', 'swarms', 'year', 'tuna'}
# Expansion terms only in Glove {'states', 'called', 'hives', 'diego', 'say', 'african', 'domestic'}
# ------------------------------
# 431 robotic technology
# Expansion terms only in rm3:  {'automated', 'computer', 'machine', 'robots', 'odetics', 'robotics', 'companies', 'robot'}
# Expansion terms only in Glove {'example', 'make', 'two', 'high', 'new', 'market', 'says', 'years'}
# ------------------------------
# 432 profiling motorists police
# Expansion terms only in rm3:  {'enforcement', 'mr', 'vehicles', 'roads', 'motorist', 'road'}
# Expansion terms only in Glove {'state', 'county', 'tickets', 'orange', 'law', 'new'}
# ------------------------------
# 433 greek philosophy stoicism
# Expansion terms only in rm3:  {'papandreou', 'military', 'change', 'mikhailidhis', 'political', 'minister', 'national', 'doctrine', 'presidency', 'greece', 'plan'}
# Expansion terms only in Glove {'director', 'chairman', 'outdoor', 'fletcher', 'barclays', 'finance', 'time', 'advertising', 'olmos', 'services', 'new'}
# ------------------------------
# 434 estonia economy
# Expansion terms only in rm3:  {'price', 'estonias', 'tallinn', 'goods', 'kroons', 'estonian', 'niitenberg', 'prices', 'kroon'}
# Expansion terms only in Glove {'russian', 'trade', 'two', 'percent', 'minister', 'world', 'cent', 'countries', 'capital'}
# ------------------------------
# 435 curbing population growth
# Expansion terms only in rm3:  {'birth', 'increase', 'year', 'curb'}
# Expansion terms only in Glove {'new', 'conference', 'cent', 'un'}
# ------------------------------
# 436 railway accidents
# Expansion terms only in rm3:  {'mr', 'fatalities', 'hse', 'accident', 'track', 'trains', 'railways', 'pounds'}
# Expansion terms only in Glove {'staff', 'workers', 'report', 'two', 'number', 'commission', 'new', 'says'}
# ------------------------------
# 437 deregulation gas electric
# Expansion terms only in rm3:  {'regional', 'energi', 'mr', 'year'}
# Expansion terms only in Glove {'new', 'competition', 'utilities', 'government'}
# ------------------------------
# 438 tourism increase
# Expansion terms only in rm3:  {'economic', 'travel', 'growth', 'increased', 'year'}
# Expansion terms only in Glove {'1993', 'world', 'china', 'new', 'years'}
# ------------------------------
# 439 inventions scientific discoveries
# Expansion terms only in rm3:  {'invention', 'companies', 'made', 'industry', 'ideas', 'discovery', 'technical', 'development', 'business'}
# Expansion terms only in Glove {'rights', 'nih', 'grant', 'product', 'time', 'world', 'new', 'institute', 'grantees'}
# ------------------------------
# 440 child labor
# Expansion terms only in rm3:  {'workers', 'day', 'occupations', 'year', 'working'}
# Expansion terms only in Glove {'1', 'time', 'session', '10', 'standards'}
# ------------------------------
# 441 lyme disease
# Expansion terms only in rm3:  {'infectious', 'infection', 'diseases', 'blood', '93', 'patients', 'medical', 'aids'}
# Expansion terms only in Glove {'california', 'long', 'deer', 'death', 'found', '1990', 'new', 'years'}
# ------------------------------
# 442 heroic acts
# Expansion terms only in rm3:  {'valiant', 'criminal', 'al', 'officers', 'text', 'great'}
# Expansion terms only in Glove {'yemeni', 'polish', 'defense', 'palestinian', 'president', 'law'}
# ------------------------------
# 443 us investment africa
# Expansion terms only in rm3:  {'african', 'africas', 'mr', 'year'}
# Expansion terms only in Glove {'new', 'capital', 'cent', 'sanctions'}
# ------------------------------
# 444 supercritical fluids
# Expansion terms only in rm3:  {'siloxanes', 'materials', 'pressure', 'wood', 'steam', 'high', 'technology', 'fluid', 'drying'}
# Expansion terms only in Glove {'organic', 'substances', 'dioxide', 'production', 'harmful', 'clean', 'standards', 'solvent', 'extremely'}
# ------------------------------
# 445 women clergy
# Expansion terms only in rm3:  {'catholic', 'priest', 'ordained', 'female', '100', 'ministry', 'womens'}
# Expansion terms only in Glove {'general', 'two', 'income', 'ft', 'likely', 'three', 'vote'}
# ------------------------------
# 446 tourists violence
# Expansion terms only in rm3:  {'dollars', 'mr', 'tourist', 'year', 'countrys', 'sector', 'hotel'}
# Expansion terms only in Glove {'state', 'police', 'two', 'people', 'militant', 'egyptian', 'country'}
# ------------------------------
# 447 stirling engine
# Expansion terms only in rm3:  {'engines', 'county', 'stirlings', 'bill', 'machines', 'water', 'merger', 'sdg', 'utility', 'scottish'}
# Expansion terms only in Glove {'new', 'launching', 'r', 'substitute', 'force', '4', 'rocket', 'acceptable', 'space', 'second'}
# ------------------------------
# 448 ship losses
# Expansion terms only in rm3:  {'marine', 'carriers', 'fleet', 'mr', 'loss', 'ferry', 'cargo', 'tonnage', 'year', 'ships', 'shipowners'}
# Expansion terms only in Glove {'years', 'skaugen', '1991', 'navy', 'two', '000', 'international', 'cent', 'ft', 'ugland', 'soviet'}
# ------------------------------
# 449 antibiotics ineffectiveness
# Expansion terms only in rm3:  {'treatment', 'effect', 'enzymes', 'activity', 'resistant', 'aminoglycoside', 'genes', 'antibiotic', 'strains', 'resistance', 'medicine', 'bacteria'}
# Expansion terms only in Glove {'kanamycin', 'administered', 'calgene', 'vegetables', 'fruits', 'people', 'neomycin', 'european', 'gastric', 'atp', 'conditions', 'spending'}
# ------------------------------
# 450 king hussein peace
# Expansion terms only in rm3:  {'mr', 'arafat', 'husseins'}
# Expansion terms only in Glove {'state', 'islamic', 'political'}
# ------------------------------
# 601 turkey iraq water
# Expansion terms only in rm3:  {'israeli', 'mr', 'turkeys', 'iraqi', 'kurdish', 'al', 'iraqs', 'turkish'}
# Expansion terms only in Glove {'gap', 'euphrates', 'foreign', 'security', 'arab', 'officials', 'peace', 'international'}
# ------------------------------
# 602 czech slovak sovereignty
# Expansion terms only in rm3:  {'lands', 'vaclav', 'mr', 'czechoslovak', 'slovakia', 'bratislava', 'czechs', 'czechoslovakia', 'slovaks'}
# Expansion terms only in Glove {'union', 'government', 'two', 'political', 'democratic', 'cent', 'independence', 'new', 'klaus'}
# ------------------------------
# 603 tobacco cigarette lawsuit
# Expansion terms only in rm3:  {'action', 'smoke', 'cigarettes', 'products'}
# Expansion terms only in Glove {'anti', 'federal', 'new', 'supreme'}
# ------------------------------
# 604 lyme disease arthritis
# Expansion terms only in rm3:  {'states', 'diseases', 'blood', '93', 'research', 'symptoms', 'cases', 'neurological', 'medical', 'health'}
# Expansion terms only in Glove {'markers', 'treatment', 'reported', 'known', 'genetic', 'high', 'found', '1990', 'new', 'years'}
# ------------------------------
# 605 great britain health care
# Expansion terms only in rm3:  {'disabled', 'life', 'british', 'food', 'insurance', 'medicine', 'companies', 'responsible'}
# Expansion terms only in Glove {'new', 'americans', 'public', 'home', 'group', 'nhs', '4', 'pounds'}
# ------------------------------
# 606 leg traps ban
# Expansion terms only in rm3:  {'trapping', 'pigeons', 'birds', 'frogs', 'racing', 'trap', 'animal', 'pigeon'}
# Expansion terms only in Glove {'60', 'coyotes', 'canada', 'listed', 'coyote', 'antonovich', 'measure', 'commission'}
# ------------------------------
# 607 human genetic code
# Expansion terms only in rm3:  {'diseases', 'proteins', 'humans', 'evidence', 'therapy'}
# Expansion terms only in Glove {'make', 'kamp', 'van', 'new', 'de'}
# ------------------------------
# 608 taxing social security
# Expansion terms only in rm3:  {'earnings', 'medicare', 'pension', 'tax', 'year', 'taxes'}
# Expansion terms only in Glove {'moynihans', '000', 'people', 'proposal', 'budget', 'years'}
# ------------------------------
# 609 per capita alcohol consumption
# Expansion terms only in rm3:  {'average', 'grain', 'income', 'countries', 'food', 'year', 'kg'}
# Expansion terms only in Glove {'5', '1988', 'trend', 'czech', 'new', 'drop', '7'}
# ------------------------------
# 610 minimum wage adverse impact
# Expansion terms only in rm3:  {'affected', 'mr', 'work', 'wages', 'job', 'hour'}
# Expansion terms only in Glove {'secretary', 'economy', 'policy', 'economic', 'blair', 'business'}
# ------------------------------
# 611 kurds germany violence
# Expansion terms only in rm3:  {'german', 'wing', 'hesse'}
# Expansion terms only in Glove {'acts', 'text', 'bfn'}
# ------------------------------
# 612 tibet protesters
# Expansion terms only in rm3:  {'monks', 'protests', 'tibets', 'india', 'buddhist'}
# Expansion terms only in Glove {'rights', 'government', 'economic', 'leader', 'human'}
# ------------------------------
# 613 berlin wall disposal
# Expansion terms only in rm3:  {'mr', 'gate', 'city', '1990', 'berliners', 'section', 'segments', 'brandenburg'}
# Expansion terms only in Glove {'away', 'home', 'trial', 'two', 'former', 'help', '4', 'honecker'}
# ------------------------------
# 614 flavr savr tomato
# Expansion terms only in rm3:  {'skin', '3', 'fresh', '1', 'makes', 'minutes', 'ripe', '4', 'market', '2', 'tomatoes'}
# Expansion terms only in Glove {'inspection', 'cfr', 'new', 'october', 'subject', 'notice', 'service', 'animal', 'gene', 'health', 'fda'}
# ------------------------------
# 615 timber exports asia
# Expansion terms only in rm3:  {'mr', 'asian', 'export', 'lumber', 'world', 'species', 'year', 'international'}
# Expansion terms only in Glove {'federal', 'zealand', 'canada', 'government', 'south', 'softwood', 'canadian', 'new'}
# ------------------------------
# 616 volkswagen mexico
# Expansion terms only in rm3:  {'volkswagens', 'mr', 'vehicles', 'mexican', 'german', 'year', 'motor', 'suppliers'}
# Expansion terms only in Glove {'workers', 'sales', 'nafta', 'industry', 'strike', 'group', 'north', 'new'}
# ------------------------------
# 617 russia cuba economy
# Expansion terms only in rm3:  {'cubas', 'russian', 'havana', 'cuban', 'year'}
# Expansion terms only in Glove {'trade', '000', 'billion', 'petroleum', 'new'}
# ------------------------------
# 618 ayatollah khomeini death
# Expansion terms only in rm3:  {'islam', 'muslim', 'khomeinis', 'rushdies', 'ayatollahs'}
# Expansion terms only in Glove {'june', '1989', 'home', 'british', 'new'}
# ------------------------------
# 619 winnie mandela scandal
# Expansion terms only in rm3:  {'stompie', 'mr', 'activist', 'mandelas', 'johannesburg', 'mrs', 'seipei'}
# Expansion terms only in Glove {'soccer', 'members', 'men', 'abducted', 'three', 'club', 'bodyguards'}
# ------------------------------
# 620 france nuclear testing
# Expansion terms only in rm3:  {'warheads', 'arms', 'mr', 'computer', 'french', 'countries', 'atomic', 'test', 'tests', 'russia'}
# Expansion terms only in Glove {'francois', 'simulation', 'pacific', 'defense', 'minister', 'world', '1995', 'energy', 'resume', 'new'}
# ------------------------------
# 621 women ordained church england
# Expansion terms only in rm3:  {'ordain', 'churches', 'news', 'woman'}
# Expansion terms only in Glove {'new', 'rev', 'communion', 'vote'}
# ------------------------------
# 622 price fixing
# Expansion terms only in rm3:  {'salmon', 'mr', 'minimum', 'fix', 'dealers', 'evidence', 'bank', 'standards', 'business', 'prices'}
# Expansion terms only in Glove {'dollars', 'yesterday', 'home', 'r', 'shipping', 'competition', 'ft', 'commission', 'x', 'court'}
# ------------------------------
# 623 toxic chemical weapon
# Expansion terms only in rm3:  {'scientific', 'russias', 'weapons', 'biological', 'destroyed'}
# Expansion terms only in Glove {'oblast', '000', 'committee', 'time', 'ministry'}
# ------------------------------
# 624 sdi star wars
# Expansion terms only in rm3:  {'arms', 'computer', 'defence', 'nuclear', 'systems', 'anti', 'ground'}
# Expansion terms only in Glove {'reagan', 'senate', 'house', 'million', 'budget', 'new', 'administration'}
# ------------------------------
# 625 arrests bombing wtc
# Expansion terms only in rm3:  {'trading', 'mr', 'trade', 'bomb', 'arrested', 'yesterday', 'pacific', 'authorities', 'exchange', 'group', 'ft', 'centre', 'company', 'arrest', 'investigation', 'tomson', 'international'}
# Expansion terms only in Glove {'groups', 'connection', 'states', 'new', 'denmark', 'terrorism', 'security', 'two', 'arab', 'arhus', 'charged', 'three', 'danish', 'jordanian', 'united', 'egyptians', 'jordan'}
# ------------------------------
# 626 human stampede
# Expansion terms only in rm3:  {'back', 'reported', 'quoted', 'rules', 'police', 'employees', 'protesters', 'stricken', 'executive', '110', 'began'}
# Expansion terms only in Glove {'least', 'state', 'general', 'pilgrims', 'city', 'saudi', 'officials', 'time', 'world', '94', 'dozens'}
# ------------------------------
# 627 russian food crisis
# Expansion terms only in rm3:  {'union', 'republics', 'year', 'social', 'russia'}
# Expansion terms only in Glove {'moscow', 'republic', 'foreign', 'new', '1994'}
# ------------------------------
# 628 us invasion panama
# Expansion terms only in rm3:  {'attack', 'panamanian', 'intervention', 'americans', 'force'}
# Expansion terms only in Glove {'army', 'city', 'soldiers', 'drug', 'new'}
# ------------------------------
# 629 abortion clinic attack
# Expansion terms only in rm3:  {'clinics', 'activists', 'abortions', 'health', 'protesters', 'womens'}
# Expansion terms only in Glove {'ruling', 'edition', 'issue', 'law', 'decision', 'supreme'}
# ------------------------------
# 630 gulf war syndrome
# Expansion terms only in rm3:  {'storm', 'toxic', 'chemical', 'nuclear', 'kuwait', 'iraq', 'american', 'japan', 'shrimp'}
# Expansion terms only in Glove {'illness', 'defence', 'suffering', '000', 'uranium', 'time', 'three', 'doctor', 'co'}
# ------------------------------
# 631 mandela south africa president
# Expansion terms only in rm3:  {'ties', 'mr', 'africas', 'mandelas', 'bush', 'african'}
# Expansion terms only in Glove {'states', 'leaders', 'meeting', 'country', 'new', 'visit'}
# ------------------------------
# ...
# ------------------------------
# 637 human growth hormone hgh
# Expansion terms only in rm3:  {'children', 'synthetic', 'athletes', 'ageing', 'hormones', 'short', 'halpern', 'muscle', 'medical', 'milk', 'health', 'body', 'disease', 'steroids'}
# Expansion terms only in Glove {'stern', 'robinson', 'dollars', 'bag', 'saying', 'magazine', 'make', 'dont', '000', 'article', 'million', 'world', 'allegations', 'three'}
# ------------------------------
# 638 wrongful convictions
# Expansion terms only in rm3:  {'mr', 'conviction', 'police', 'convicted', 'year'}
# Expansion terms only in Glove {'brown', 'authority', 'howard', 'new', 'body'}
# ------------------------------
# 639 consumer line shopping
# Expansion terms only in rm3:  {'shop', 'consumers', 'mr', 'shoppers', 'shops', 'year'}
# Expansion terms only in Glove {'christmas', 'computer', 'make', 'time', 'says', 'years'}
# ------------------------------
# 640 maternity leave policies
# Expansion terms only in rm3:  {'employees', 'law', 'family', 'job', 'working'}
# Expansion terms only in Glove {'government', 'ft', 'commission', 'new', 'statutory'}
# ------------------------------
# 641 valdez wildlife marine life
# Expansion terms only in rm3:  {'prince', 'bay', 'waters'}
# Expansion terms only in Glove {'million', 'state', 'cleanup'}
# ------------------------------
# 642 tiananmen square protesters
# Expansion terms only in rm3:  {'peoples', 'army', 'protests', 'protest', 'beijings'}
# Expansion terms only in Glove {'june', 'two', 'political', 'news', 'years'}
# ------------------------------
# 643 salmon dams pacific northwest
# Expansion terms only in rm3:  {'dam', 'aluminium', 'amendments', 'water', 'sturgeon', 'wildlife', 'environmental', 'portland'}
# Expansion terms only in Glove {'bureau', 'director', '000', '1', 'act', 'recommendations', 'reclamation', 'information'}
# ------------------------------
# 644 exotic animals import
# Expansion terms only in rm3:  {'imported', 'vegetables', 'animal'}
# Expansion terms only in Glove {'part', 'state', '2'}
# ------------------------------
# 645 software piracy
# Expansion terms only in rm3:  {'copies', 'losses', 'news', 'ft', 'copying'}
# Expansion terms only in Glove {'percent', 'cent', 'european', 'law', 'personal'}
# ------------------------------
# 646 food stamps increase
# Expansion terms only in rm3:  {'tfp', 'stamp', 'nutrition', 'recipients'}
# Expansion terms only in Glove {'new', 'e', '7', 'department'}
# ------------------------------
# 647 windmill electricity
# Expansion terms only in rm3:  {'utilities', 'mr', 'farm', 'industry', 'coal', 'windmills', 'year', 'generating', 'environmental', 'solar'}
# Expansion terms only in Glove {'kilowatt', 'denmark', 'costs', 'megawatts', 'million', 'installations', 'built', 'cents', 'hour', 'years'}
# ------------------------------
# 648 family leave law
# Expansion terms only in rm3:  {'opm', 'adoption', 'year', 'member'}
# Expansion terms only in Glove {'time', 'public', 'r', 'x'}
# ------------------------------
# 649 computer viruses
# Expansion terms only in rm3:  {'network', 'computers', 'virus'}
# Expansion terms only in Glove {'friday', 'says', 'experts'}
# ------------------------------
# 650 tax evasion indicted
# Expansion terms only in rm3:  {'indictment', 'fraud', 'million', 'conspiracy', 'payola'}
# Expansion terms only in Glove {'gioiosa', 'diego', 'three', 'gotti', 'investigation'}
# ------------------------------
# 651 us ethnic population
# Expansion terms only in rm3:  {'serbian', 'mr', 'black', 'asian', 'national', 'group', 'latino', 'minority'}
# Expansion terms only in Glove {'peoples', 'un', 'percent', 'war', 'moslems', 'republic', 'bosnia', 'international'}
# ------------------------------
# 652 oic balkans 1990s
# Expansion terms only in rm3:  {'support', 'malaysia', 'peace', 'text', 'decision', 'serbs'}
# Expansion terms only in Glove {'turkey', 'alatas', 'contact', 'un', 'turkish', 'international'}
# ------------------------------
# 653 eta basque terrorism
# Expansion terms only in rm3:  {'attack', 'mr', 'fatherland', 'text', 'basques', 'garcia'}
# Expansion terms only in Glove {'two', 'terrorist', 'added', '94', 'belloch', 'investigation'}
# ------------------------------
# 654 sex schools
# Expansion terms only in rm3:  {'school', 'independent', 'results', 'taught', 'play', 'year'}
# Expansion terms only in Glove {'unified', 'grades', 'board', 'co', 'aids', 'years'}
# ------------------------------
# 655 add diagnosis treatment
# Expansion terms only in rm3:  {'condition', 'procedures', 'psychiatric', 'clinical', 'physicians', 'management', 'diagnostic', 'facility'}
# Expansion terms only in Glove {'ahcpr', '4', 'act', 'drg', 'section', 'b', 'part', 'esrd'}
# ------------------------------
# 656 lead poisoning children
# Expansion terms only in rm3:  {'study', 'products', 'young', 'child', 'environmental'}
# Expansion terms only in Glove {'regulations', 'new', 'public', '2', 'part'}
# ------------------------------
# 657 school prayer banned
# Expansion terms only in rm3:  {'schools', 'church', 'government', 'home', 'ban', 'people', 'al', 'prayers'}
# Expansion terms only in Glove {'clubs', 'federal', 'case', 'amendment', 'football', 'rep', 'x', 'supreme'}
# ------------------------------
# 658 teenage pregnancy
# Expansion terms only in rm3:  {'care', 'mr', 'work', 'pregnancies', 'young', 'sex', 'people', 'year'}
# Expansion terms only in Glove {'secretary', 'independent', 'program', 'pilot', 'bottomley', 'mp', 'new', 'applicants'}
# ------------------------------
# 659 cruise health safety
# Expansion terms only in rm3:  {'boats', 'mr', 'missile', 'missiles', 'cruises', 'year', 'warheads'}
# Expansion terms only in Glove {'hunt', 'kuchiyev', 'did', 'icebreaker', 'medical', 'new', 'years'}
# ------------------------------
# 660 whale watching california
# Expansion terms only in rm3:  {'bay', 'day', 'mammal', 'whales', 'beach', 'fisheries', 'boaters', 'cruises'}
# Expansion terms only in Glove {'close', 'call', 'two', '000', '10', 'baja', 'pm', 'dana'}
# ------------------------------
# 661 melanoma treatment causes
# Expansion terms only in rm3:  {'bowel', 'treatments', 'antibodies', 'medical', 'year'}
# Expansion terms only in Glove {'scientists', 'researchers', 'trials', 'new', 'years'}
# ------------------------------
# 662 telemarketer protection
# Expansion terms only in rm3:  {'sales', 'edition', 'public', 'number', 'telemarketers', 'cmrs'}
# Expansion terms only in Glove {'county', 'federal', 'calls', '000', 'fax', 't'}
# ------------------------------
# 663 agent orange exposure
# Expansion terms only in rm3:  {'problems', 'claims', 'assistance', 'chemical', '000', 'cancers', 'million', 'herbicides'}
# Expansion terms only in Glove {'secretary', 'benefits', 'cdc', 'federal', 'affairs', 'house', 'law', 'va'}
# ------------------------------
# 664 american indian museum
# Expansion terms only in rm3:  {'000', 'indians', 'tribes', 'foundation', 'yorks'}
# Expansion terms only in Glove {'bill', 'art', 'tuesday', 'new', 'chumash'}
# ------------------------------
# 665 poverty africa sub sahara
# Expansion terms only in rm3:  {'poor', 'africas', 'developing', 'year', 'african', 'health', 'asia'}
# Expansion terms only in Glove {'adjustment', 'dollars', 'crisis', 'policies', 'says', 'governments', 'region'}
# ------------------------------
# 666 thatcher resignation impact
# Expansion terms only in rm3:  {'lawson', 'lady', 'britain', 'thatchers', 'chancellor'}
# Expansion terms only in Glove {'conservative', 'leadership', 'major', 'former', 'heseltine'}
# ------------------------------
# 667 unmarried partner households
# Expansion terms only in rm3:  {'single', 'divorce', 'population', 'homosexual', 'partners', 'married', 'traditional', 'women', 'years'}
# Expansion terms only in Glove {'1986', 'live', '1980', 'time', '1970', 'census', 'new', '1960', 'living'}
# ------------------------------
# 668 poverty disease
# Expansion terms only in rm3:  {'diseases', 'costs', 'rate', 'social', 'problem', 'year'}
# Expansion terms only in Glove {'workers', 'prevention', 'province', 'incidence', 'high', 'paper'}
# ------------------------------
# 669 islamic revolution
# Expansion terms only in rm3:  {'islam', 'muslim', 'persian', 'hashemi', 'majles', 'iranian', 'khamenei'}
# Expansion terms only in Glove {'nation', 'victory', 'today', 'great', 'system', 'presence', 'years'}
# ------------------------------
# 670 us elections apathy
# Expansion terms only in rm3:  {'voting', 'election', 'mr', 'local'}
# Expansion terms only in Glove {'part', 'absentee', 'home', 'april'}
# ------------------------------
# 671 salvation army benefits
# Expansion terms only in rm3:  {'military', 'mr', 'moslem', 'charitys', 'officials', 'project', 'investigation'}
# Expansion terms only in Glove {'valley', 'dollars', 'money', 'yesterday', 'made', 'two', '000'}
# ------------------------------
# 672 nra membership profile
# Expansion terms only in rm3:  {'mr', 'chief', 'rivers', '000', 'office', 'committee', 'water', 'nras', 'year', 'environmental', 'pounds', 'executive'}
# Expansion terms only in Glove {'convention', 'senate', 'ban', 'people', 'weapons', 'firearms', 'million', 'assault', 'president', 'vote', 'law', 'new'}
# ------------------------------
# 673 soviet withdrawal afghanistan
# Expansion terms only in rm3:  {'afghan', 'army', 'soviets'}
# Expansion terms only in Glove {'feb', 'home', '15'}
# ------------------------------
# 674 greenpeace prosecuted
# Expansion terms only in rm3:  {'organization', 'greenpeaces', 'thorp', 'pressure', 'campaign', 'navy', 'public', 'plant', 'bnf'}
# Expansion terms only in Glove {'pollution', 'products', 'two', 'water', 'company', 'dumping', 'companies', 'says', 'waste'}
# ------------------------------
# 675 olympics training swimming
# Expansion terms only in rm3:  {'trials', 'program', 'pool', 'event', 'olympic', 'coaches'}
# Expansion terms only in Glove {'200', 'won', 'neilson', 'long', '1', '100'}
# ------------------------------
# 676 poppy cultivation
# Expansion terms only in rm3:  {'seeds', 'areas', 'land', 'poppies', 'production', 'text', 'control', 'area'}
# Expansion terms only in Glove {'san', 'work', '000', 'national', 'department', 'ministry', 'cocaine', 'years'}
# ------------------------------
# 677 leaning tower pisa
# Expansion terms only in rm3:  {'climb', 'century', 'marble', 'world', 'towers', 'built', 'year', 'team', '14th', '94'}
# Expansion terms only in Glove {'tourists', 'close', '20', 'work', 'month', 'bre', 'stabilise', 'steel', 'help', 'says'}
# ------------------------------
# 678 joint custody impact
# Expansion terms only in rm3:  {'rights', 'wayne', 'attack', 'trial', 'material', 'parent'}
# Expansion terms only in Glove {'mothers', 'mother', 'new', 'decision', 'says', 'years'}
# ------------------------------
# 679 opening adoption records
# Expansion terms only in rm3:  {'program', 'government', 'adoptions', 'park', 'system', 'year', 'agency'}
# Expansion terms only in Glove {'california', 'court', 'home', '1', 'adoptive', 'rule', 'years'}
# ------------------------------
# 680 immigrants spanish school
# Expansion terms only in rm3:  {'latinos', 'schools', 'limited', 'immigrant', 'year', 'perez'}
# Expansion terms only in Glove {'college', 'districts', 'angeles', '000', 'parents', 'say'}
# ------------------------------
# 681 wind power location
# Expansion terms only in rm3:  {'winds', 'fires', 'powered', 'solar', 'plants'}
# Expansion terms only in Glove {'generators', '000', '10', 'shall', 'new'}
# ------------------------------
# 682 adult immigrants english
# Expansion terms only in rm3:  {'spanish', '000', 'immigrant'}
# Expansion terms only in Glove {'angeles', 'los', 'years'}
# ------------------------------
# 683 czechoslovakia breakup
# Expansion terms only in rm3:  {'strategy', 'union', 'army', 'nuclear', 'minister', 'text', 'north', 'paper'}
# Expansion terms only in Glove {'fact', 'two', 'percent', 'political', 'national', 'european', 'new', 'moravcik'}
# ------------------------------
# 684 part time benefits
# Expansion terms only in rm3:  {'benefit', 'back', 'mr', 'year'}
# Expansion terms only in Glove {'social', 'security', 'labour', 'women'}
# ------------------------------
# 685 oscar winner selection
# Expansion terms only in rm3:  {'winners', 'director', 'directors', 'box', 'office', 'oscars', 'critics'}
# Expansion terms only in Glove {'3', 'man', 'best', 'edition', 'home', '1', '2'}
# ------------------------------
# 686 argentina pegging dollar
# Expansion terms only in rm3:  {'mr', 'dollars', 'pegged', 'argentine', 'argentinas', 'brazil', 'year'}
# Expansion terms only in Glove {'economy', '1991', 'central', 'month', 'ft', 'prices', 'years'}
# ------------------------------
# 687 northern ireland industry
# Expansion terms only in rm3:  {'irish', 'mr', 'belfast', 'public', 'irelands', 'european', 'employment', 'republic', 'sector'}
# Expansion terms only in Glove {'state', 'economic', '000', 'office', 'province', 'hualon', 'new', 'pounds', 'says'}
# ------------------------------
# 688 non us media bias
# Expansion terms only in rm3:  {'mr', 'kcet', 'program', 'station', 'year', 'electoral', 'biased'}
# Expansion terms only in Glove {'public', 'political', 'national', 'time', 'new', 'african', 'says'}
# ------------------------------
# 689 family planning aid
# Expansion terms only in rm3:  {'programs', 'financial', 'percentages', 'families', 'national', 'year', 'plan', 'abortion', 'women'}
# Expansion terms only in Glove {'000', 'percent', '1', 'house', 'million', 'child', 'services', 'social', 'x'}
# ------------------------------
# 690 college education advantage
# Expansion terms only in rm3:  {'colleges', 'educational', 'programs', 'year'}
# Expansion terms only in Glove {'new', 'commission', 'bonds', 'city'}
# ------------------------------
# 691 clear cutting forests
# Expansion terms only in rm3:  {'areas', 'land', 'cut', 'environment', 'companies', 'forest'}
# Expansion terms only in Glove {'california', '000', 'measure', 'service', 'new', 'says'}
# ------------------------------
# 692 prostate cancer detection treatment
# Expansion terms only in rm3:  {'cancers', 'growth', 'beam', 'year', 'gene', 'tests'}
# Expansion terms only in Glove {'8', '000', 'adults', '10', 'new', 'years'}
# ------------------------------
# 693 newspapers electronic media
# Expansion terms only in rm3:  {'military', 'newspaper', 'print', 'multimedia', 'stories', 'year', 'technology', 'regional', 'international'}
# Expansion terms only in Glove {'government', 'radio', 'people', 'readers', 'time', 'ft', 'company', 'new', 'line'}
# ------------------------------
# 694 compost pile
# Expansion terms only in rm3:  {'garbage', 'composted', 'zeke', 'solid', 'home', 'product', 'city', 'dundon', 'recycling', 'found', 'composting', 'heap'}
# Expansion terms only in Glove {'least', 'buried', 'days', 'covered', 'yard', 'end', 'time', 'spread', '30', '6', 'quarantined', 'infected'}
# ------------------------------
# 695 white collar crime sentence
# Expansion terms only in rm3:  {'involved', 'term', 'larouche', 'crimes', 'criminals', 'securities', 'year', 'sentences'}
# Expansion terms only in Glove {'bargaining', 'justice', 'financial', 'trial', 'people', 'minkow', 'guilty', 'law'}
# ------------------------------
# 696 safety plastic surgery
# Expansion terms only in rm3:  {'surgeries', 'face', 'devices', 'surgeon', 'year', 'operations'}
# Expansion terms only in Glove {'dow', 'new', 'board', 'fda', 'says', 'years'}
# ------------------------------
# 697 air traffic controller
# Expansion terms only in rm3:  {'flight', 'aircraft', 'controllers', 'airports', 'international'}
# Expansion terms only in Glove {'union', 'angeles', 'coast', 'orange', 'new'}
# ------------------------------
# 698 literacy rates africa
# Expansion terms only in rm3:  {'indicators', 'malawi', 'nations', 'rate', 'south', 'world', 'countries', 'nigeria', 'african'}
# Expansion terms only in Glove {'3', '1993', 'capita', 'income', 'expectancy', '6', 'gdp', '2', 'index'}
# ------------------------------
# 699 term limits
# Expansion terms only in rm3:  {'members', 'limit', 'political'}
# Expansion terms only in Glove {'140', 'two', 'proposition'}
# ------------------------------
# 700 gasoline tax us
# Expansion terms only in rm3:  {'taxes', 'mixture', 'sales'}
# Expansion terms only in Glove {'money', 'new', 'section'}
# ------------------------------
